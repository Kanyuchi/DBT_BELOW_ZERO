# %%
# we will need the credentials we saved in the .env file
from dotenv import dotenv_values

# We also will need SQLAlchemy and its functions
from sqlalchemy import create_engine, types
from sqlalchemy.dialects.postgresql import JSON as postgres_json

import pandas as pd

# requests library will make the API calls. 
# the json package will parse the JSON string and convert it to Python data structures
import requests
import json

# with 'datetime' we want to catch the timestamp of the API call. For the actuality reference. 
# and 'time' for slowing down a .bit
from datetime import datetime
import time

# %% [markdown]
# Defining Airports Our flight Data is from 2019-01-01 until 2019-01-31. we will use the same period for the meteostat JSON API.

# %%
airport_staids = {
    'ORD': 72530
    ,'MSP': 72658
    ,'DTW': 72537
    ,'MKE': 72640
    ,'CLE': 72524
           }

# %% [markdown]
# Defining the period

# %%
period_start = "2019-01-01"
period_end = "2019-01-31"

# %%
pd.date_range(start='01/01/2029', end='31/01/2029', freq='MS')
# Out:
# DatetimeIndex(['2029-01-01'], dtype='datetime64[ns]', freq='MS')

# %%
pd.date_range(start='01/01/2019', end='31/01/2019', freq='MS') + pd.offsets.MonthEnd()
# Out:
# DatetimeIndex(['2019-01-31'], dtype='datetime64[ns]', freq=None)

# %%
first_days = pd.date_range(start='01/01/2019', end='31/01/2019', freq='MS')
last_days = first_days + pd.offsets.MonthEnd() # see, what we did here? DRY rules! :)

# %% [markdown]
# #### ... and make it lists of strings

# %%
first_days_list = first_days.strftime('%Y-%m-%d').tolist()
last_days_list = last_days.strftime('%Y-%m-%d').tolist()

# %%
print(first_days_list) 
print(last_days_list)
# Out:
# ['2019-01-01']
# ['2019-01-31']

# %% [markdown]
# Loading API Key

# %%
config = dotenv_values()
config.keys
# Out:
# <function OrderedDict.keys>

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()
api_key = config['X-RapidAPI-Key']

# %% [markdown]
# ### Test: For-loop generating the querystrings

# %%
airport_staids
# Out:
# {'ORD': 72530, 'MSP': 72658, 'DTW': 72537, 'MKE': 72640, 'CLE': 72524}

# %%
import time

for airport in airport_staids:
    print(airport)
    
    for onemonth in zip(first_days_list, last_days_list):
    
        querystring = {
            "station":airport_staids[airport]
            ,"first_day_list": onemonth[0]  # Replace ??? with the appropriate value for the start date
            ,"last_day_list": onemonth[1]    # Replace ??? with the appropriate value for the end date
            ,"model":"true"
        }
         
        print(querystring, end="\r")
       
        time.sleep(0.34)
    print()
# Out:
# ORD
# {'station': 72530, 'first_day_list': '2019-01-01', 'last_day_list': '2019-01-31', 'model': 'true'}
# MSP
# {'station': 72658, 'first_day_list': '2019-01-01', 'last_day_list': '2019-01-31', 'model': 'true'}
# DTW
# {'station': 72537, 'first_day_list': '2019-01-01', 'last_day_list': '2019-01-31', 'model': 'true'}
# MKE
# {'station': 72640, 'first_day_list': '2019-01-01', 'last_day_list': '2019-01-31', 'model': 'true'}
# CLE
# {'station': 72524, 'first_day_list': '2019-01-01', 'last_day_list': '2019-01-31', 'model': 'true'}

# %%
# testing for-loop: querystring for each airport

for airport in airport_staids:
   
    querystring = {
        "station": airport_staids[airport]
        ,"start": period_start
        ,"end": period_end
        ,"model":"true"
    }
    print(airport, "\n", querystring)
# Out:
# ORD
#  {'station': 72530, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}
# MSP
#  {'station': 72658, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}
# DTW
#  {'station': 72537, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}
# MKE
#  {'station': 72640, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}
# CLE
#  {'station': 72524, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}

# %% [markdown]
# ### API CALL hourly ( per station)

# %%
#  let's catch each response in a dictionary. create an empty dictionary with the following keys:
weather_hourly_dict = {'extracted_at':[], 
                       'airport_code':[], 
                       'station_id':[], 
                       'extracted_data':[]}

# API CALL hourly (station) - for the syntax: see the rapidapi interface

url = "https://meteostat.p.rapidapi.com/stations/hourly"

headers = {
        "X-RapidAPI-Key": api_key,
        "X-RapidAPI-Host": "meteostat.p.rapidapi.com"
}


# double for-loop for the querystrings
for airport in airport_staids:
    
    # adding some logs
    print(airport) 
    
    for onemonth in zip(first_days_list, last_days_list):
    
        querystring = {
            "station":airport_staids[airport]
            ,"start":onemonth[0]
            ,"end":onemonth[1]
            ,"model":"true"
        }
        
        # making one call with the current querystring
        response = requests.get(url, headers=headers, params=querystring)
        
        # adding some logs to catch errors
        if response.status_code != 200:
            print(f'status code {response.status_code} -> research error')
            print(querystring, end="\n\n")
        else:
            print(querystring, end="\r")
        
        # appending data to the dictionary:
        weather_hourly_dict['extracted_at'].append(datetime.now())                # timestamp,
        weather_hourly_dict['airport_code'].append(airport)                       # airport code
        weather_hourly_dict['station_id'].append(airport_staids[airport])         # weater Station ID
        weather_hourly_dict['extracted_data'].append(json.loads(response.text))   # JSON string
        
        time.sleep(0.34)
        
    print()
# Out:
# ORD
# {'station': 72530, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}
# MSP
# {'station': 72658, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}
# DTW
# {'station': 72537, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}
# MKE
# {'station': 72640, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}
# CLE
# {'station': 72524, 'start': '2019-01-01', 'end': '2019-01-31', 'model': 'true'}

# %%
# checking the dictionary
weather_hourly_dict
# Out:
# {'extracted_at': [datetime.datetime(2024, 10, 16, 12, 43, 8, 312947),
#   datetime.datetime(2024, 10, 16, 12, 43, 9, 188164),
#   datetime.datetime(2024, 10, 16, 12, 43, 10, 64336),
#   datetime.datetime(2024, 10, 16, 12, 43, 10, 950486),
#   datetime.datetime(2024, 10, 16, 12, 43, 11, 732107)],
#  'airport_code': ['ORD', 'MSP', 'DTW', 'MKE', 'CLE'],
#  'station_id': [72530, 72658, 72537, 72640, 72524],
#  'extracted_data': [{'meta': {'generated': '2024-10-16 10:43:08'},
#    'data': [{'time': '2019-01-01 00:00:00',
#      'temp': 2.8,
#      'dwpt': 2.2,
#      'rhum': 96.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 360.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1001.7,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-01 01:00:00',
#      'temp': 2.2,
#      'dwpt': 1.6,
#      'rhum': 96.0,
#      'prcp': 1.3,
#      'snow': None,
#      'wdir': 360.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1002.6,
#      'tsun': None,
#      'coco': 12},
#     {'time': '2019-01-01 02:00:00',
#      'temp': 1.1,
#      'dwpt': 0.5,
#      'rhum': 96.0,
#      'prcp': 0.2,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1005.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-01 03:00:00',
#      'temp': 1.1,
#      'dwpt': 0.5,
#      'rhum': 96.0,
#      'prcp': 0.5,
#      'snow': None,
#      'wdir': 320.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1008.1,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-01 04:00:00',
#      'temp': 1.1,
#      'dwpt': 0.5,
#      'rhum': 96.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 310.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1010.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-01 05:00:00',
#      'temp': 1.1,
#      'dwpt': 0.5,
#      'rhum': 96.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None,
#      'coco': 12},
#     {'time': '2019-01-01 06:00:00',
#      'temp': 1.1,
#      'dwpt': 0.5,
#      'rhum': 96.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1014.7,
#      'tsun': None,
#      'coco': 12},
#     {'time': '2019-01-01 07:00:00',
#      'temp': 1.1,
#      'dwpt': -0.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 330.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 08:00:00',
#      'temp': 0.6,
#      'dwpt': -0.6,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 320.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1017.5,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-01 09:00:00',
#      'temp': 0.0,
#      'dwpt': -0.6,
#      'rhum': 96.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 330.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1018.8,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 10:00:00',
#      'temp': 0.0,
#      'dwpt': -1.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1020.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 11:00:00',
#      'temp': -0.6,
#      'dwpt': -1.7,
#      'rhum': 92.0,
#      'prcp': 0.3,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1020.8,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-01 12:00:00',
#      'temp': -1.1,
#      'dwpt': -2.2,
#      'rhum': 92.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 360.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1022.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-01 13:00:00',
#      'temp': -1.7,
#      'dwpt': -3.3,
#      'rhum': 89.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1023.0,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 14:00:00',
#      'temp': -1.7,
#      'dwpt': -4.4,
#      'rhum': 82.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 20.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1024.9,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 15:00:00',
#      'temp': -2.2,
#      'dwpt': -4.4,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1025.7,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 16:00:00',
#      'temp': -2.2,
#      'dwpt': -4.4,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 360.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1026.4,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 17:00:00',
#      'temp': -2.2,
#      'dwpt': -4.4,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1026.7,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 18:00:00',
#      'temp': -2.2,
#      'dwpt': -5.0,
#      'rhum': 81.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1026.6,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-01 19:00:00',
#      'temp': -2.8,
#      'dwpt': -5.0,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1026.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-01 20:00:00',
#      'temp': -2.8,
#      'dwpt': -5.0,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1026.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-01 21:00:00',
#      'temp': -2.8,
#      'dwpt': -5.0,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1026.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 22:00:00',
#      'temp': -3.3,
#      'dwpt': -5.6,
#      'rhum': 84.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1026.9,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-01 23:00:00',
#      'temp': -3.3,
#      'dwpt': -5.6,
#      'rhum': 84.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 340.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1027.1,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 00:00:00',
#      'temp': -3.3,
#      'dwpt': -5.6,
#      'rhum': 84.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 330.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1027.5,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 01:00:00',
#      'temp': -3.3,
#      'dwpt': -5.6,
#      'rhum': 84.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 330.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1027.8,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 02:00:00',
#      'temp': -3.3,
#      'dwpt': -5.6,
#      'rhum': 84.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 330.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1027.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 03:00:00',
#      'temp': -3.3,
#      'dwpt': -5.0,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 310.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1027.1,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 04:00:00',
#      'temp': -3.3,
#      'dwpt': -5.0,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 320.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1026.7,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 05:00:00',
#      'temp': -3.3,
#      'dwpt': -5.0,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 350.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1026.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 06:00:00',
#      'temp': -3.3,
#      'dwpt': -4.4,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 323.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1026.0,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-02 07:00:00',
#      'temp': -3.3,
#      'dwpt': -4.4,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 311.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1025.8,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 08:00:00',
#      'temp': -3.3,
#      'dwpt': -4.4,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 298.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1025.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 09:00:00',
#      'temp': -2.8,
#      'dwpt': -4.4,
#      'rhum': 89.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1025.0,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 10:00:00',
#      'temp': -2.8,
#      'dwpt': -4.4,
#      'rhum': 89.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1024.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 11:00:00',
#      'temp': -2.8,
#      'dwpt': -3.9,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1023.8,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 12:00:00',
#      'temp': -2.2,
#      'dwpt': -3.9,
#      'rhum': 88.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 200.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1023.7,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-02 13:00:00',
#      'temp': -2.2,
#      'dwpt': -3.3,
#      'rhum': 92.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 200.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1023.0,
#      'tsun': None,
#      'coco': 10},
#     {'time': '2019-01-02 14:00:00',
#      'temp': -1.7,
#      'dwpt': -2.8,
#      'rhum': 92.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 200.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1022.9,
#      'tsun': None,
#      'coco': 10},
#     {'time': '2019-01-02 15:00:00',
#      'temp': -1.7,
#      'dwpt': -2.8,
#      'rhum': 92.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 200.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1023.2,
#      'tsun': None,
#      'coco': 10},
#     {'time': '2019-01-02 16:00:00',
#      'temp': -1.1,
#      'dwpt': -2.2,
#      'rhum': 92.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1021.9,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-02 17:00:00',
#      'temp': -1.1,
#      'dwpt': -2.8,
#      'rhum': 88.0,
#      'prcp': 0.3,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1020.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-02 18:00:00',
#      'temp': -1.7,
#      'dwpt': -3.3,
#      'rhum': 89.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1018.9,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 19:00:00',
#      'temp': -1.7,
#      'dwpt': -3.9,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-02 20:00:00',
#      'temp': -1.7,
#      'dwpt': -3.9,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1017.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 21:00:00',
#      'temp': -1.7,
#      'dwpt': -3.9,
#      'rhum': 85.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1016.6,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 22:00:00',
#      'temp': -1.7,
#      'dwpt': -5.0,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1016.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-02 23:00:00',
#      'temp': -1.7,
#      'dwpt': -5.5,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1015.9,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-03 00:00:00',
#      'temp': -1.7,
#      'dwpt': -5.0,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1016.4,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-03 01:00:00',
#      'temp': -1.7,
#      'dwpt': -5.0,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-03 02:00:00',
#      'temp': -2.2,
#      'dwpt': -6.0,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1018.5,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-03 03:00:00',
#      'temp': -2.2,
#      'dwpt': -6.8,
#      'rhum': 71.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1018.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-03 04:00:00',
#      'temp': -2.8,
#      'dwpt': -6.6,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 05:00:00',
#      'temp': -2.8,
#      'dwpt': -6.1,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 06:00:00',
#      'temp': -3.3,
#      'dwpt': -6.1,
#      'rhum': 81.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1017.6,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-03 07:00:00',
#      'temp': -3.3,
#      'dwpt': -6.1,
#      'rhum': 81.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1017.6,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 08:00:00',
#      'temp': -3.9,
#      'dwpt': -6.1,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1017.6,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 09:00:00',
#      'temp': -3.9,
#      'dwpt': -6.1,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1018.3,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 10:00:00',
#      'temp': -3.9,
#      'dwpt': -6.1,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1017.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 11:00:00',
#      'temp': -4.4,
#      'dwpt': -6.1,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 200.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1017.2,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 12:00:00',
#      'temp': -4.4,
#      'dwpt': -6.1,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 13:00:00',
#      'temp': -4.4,
#      'dwpt': -6.1,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1017.8,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 14:00:00',
#      'temp': -4.4,
#      'dwpt': -5.6,
#      'rhum': 91.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1018.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 15:00:00',
#      'temp': -3.3,
#      'dwpt': -5.0,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1018.1,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 16:00:00',
#      'temp': -1.7,
#      'dwpt': -5.0,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1018.2,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 17:00:00',
#      'temp': 0.0,
#      'dwpt': -5.0,
#      'rhum': 69.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 18:00:00',
#      'temp': 1.7,
#      'dwpt': -4.0,
#      'rhum': 66.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1016.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 19:00:00',
#      'temp': 2.2,
#      'dwpt': -3.3,
#      'rhum': 67.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 20:00:00',
#      'temp': 3.3,
#      'dwpt': -2.9,
#      'rhum': 64.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 21:00:00',
#      'temp': 3.3,
#      'dwpt': -2.2,
#      'rhum': 67.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1014.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 22:00:00',
#      'temp': 3.3,
#      'dwpt': -2.2,
#      'rhum': 67.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1013.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-03 23:00:00',
#      'temp': 2.8,
#      'dwpt': -1.7,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 00:00:00',
#      'temp': 2.8,
#      'dwpt': -1.7,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1014.1,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 01:00:00',
#      'temp': 2.2,
#      'dwpt': -1.8,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 02:00:00',
#      'temp': 2.2,
#      'dwpt': -1.8,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 03:00:00',
#      'temp': 1.7,
#      'dwpt': -1.7,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 04:00:00',
#      'temp': 1.1,
#      'dwpt': -1.6,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1013.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 05:00:00',
#      'temp': 1.1,
#      'dwpt': -1.6,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-04 06:00:00',
#      'temp': 0.6,
#      'dwpt': -2.1,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-04 07:00:00',
#      'temp': 0.6,
#      'dwpt': -2.1,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1011.9,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-04 08:00:00',
#      'temp': 0.6,
#      'dwpt': -2.1,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1011.7,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-04 09:00:00',
#      'temp': 0.0,
#      'dwpt': -2.9,
#      'rhum': 81.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1010.9,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-04 10:00:00',
#      'temp': 0.0,
#      'dwpt': -2.9,
#      'rhum': 81.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1010.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 11:00:00',
#      'temp': -0.6,
#      'dwpt': -2.8,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1009.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 12:00:00',
#      'temp': 0.0,
#      'dwpt': -3.4,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1010.1,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-04 13:00:00',
#      'temp': -0.6,
#      'dwpt': -3.3,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 200.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1009.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 14:00:00',
#      'temp': 0.0,
#      'dwpt': -2.9,
#      'rhum': 81.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1010.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 15:00:00',
#      'temp': 1.1,
#      'dwpt': -2.8,
#      'rhum': 75.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1010.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 16:00:00',
#      'temp': 2.8,
#      'dwpt': -2.1,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1009.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 17:00:00',
#      'temp': 4.4,
#      'dwpt': -2.2,
#      'rhum': 62.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1008.6,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 18:00:00',
#      'temp': 6.7,
#      'dwpt': -1.7,
#      'rhum': 55.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1007.5,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 19:00:00',
#      'temp': 7.8,
#      'dwpt': -1.7,
#      'rhum': 51.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1006.2,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 20:00:00',
#      'temp': 8.3,
#      'dwpt': -2.1,
#      'rhum': 48.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1005.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 21:00:00',
#      'temp': 8.9,
#      'dwpt': -2.1,
#      'rhum': 46.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1005.2,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 22:00:00',
#      'temp': 8.3,
#      'dwpt': -1.0,
#      'rhum': 52.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1005.2,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-04 23:00:00',
#      'temp': 6.7,
#      'dwpt': -1.0,
#      'rhum': 58.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 280.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1005.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 00:00:00',
#      'temp': 4.4,
#      'dwpt': -0.6,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1006.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 01:00:00',
#      'temp': 3.9,
#      'dwpt': -0.7,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1006.6,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 02:00:00',
#      'temp': 2.8,
#      'dwpt': -0.7,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1006.8,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 03:00:00',
#      'temp': 2.2,
#      'dwpt': -0.6,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1007.1,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 04:00:00',
#      'temp': 1.7,
#      'dwpt': -0.6,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1007.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 05:00:00',
#      'temp': 1.7,
#      'dwpt': -0.6,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1006.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 06:00:00',
#      'temp': 1.1,
#      'dwpt': -0.7,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1006.6,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-05 07:00:00',
#      'temp': 0.6,
#      'dwpt': -1.2,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1006.9,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-05 08:00:00',
#      'temp': 1.1,
#      'dwpt': -1.1,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1007.6,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 09:00:00',
#      'temp': 0.6,
#      'dwpt': -1.2,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1007.9,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-05 10:00:00',
#      'temp': 0.6,
#      'dwpt': -1.6,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 7.6,
#      'wpgt': None,
#      'pres': 1007.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 11:00:00',
#      'temp': 0.0,
#      'dwpt': -1.8,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1007.6,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 12:00:00',
#      'temp': 0.0,
#      'dwpt': -1.8,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1008.5,
#      'tsun': None,
#      'coco': 1},
#     {'time': '2019-01-05 13:00:00',
#      'temp': 0.0,
#      'dwpt': -1.8,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1009.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 14:00:00',
#      'temp': 0.6,
#      'dwpt': -1.2,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1010.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 15:00:00',
#      'temp': 1.7,
#      'dwpt': -0.6,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1010.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 16:00:00',
#      'temp': 4.4,
#      'dwpt': 0.5,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1011.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 17:00:00',
#      'temp': 6.1,
#      'dwpt': 1.0,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1010.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 18:00:00',
#      'temp': 8.3,
#      'dwpt': 1.7,
#      'rhum': 63.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1010.2,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 19:00:00',
#      'temp': 9.4,
#      'dwpt': 2.3,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1010.1,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 20:00:00',
#      'temp': 10.6,
#      'dwpt': 2.2,
#      'rhum': 56.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1010.6,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 21:00:00',
#      'temp': 11.1,
#      'dwpt': 2.9,
#      'rhum': 57.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1011.2,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-05 22:00:00',
#      'temp': 10.6,
#      'dwpt': 2.9,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1012.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-05 23:00:00',
#      'temp': 8.9,
#      'dwpt': 2.2,
#      'rhum': 63.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-06 00:00:00',
#      'temp': 7.2,
#      'dwpt': 2.9,
#      'rhum': 74.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1013.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 01:00:00',
#      'temp': 6.1,
#      'dwpt': 2.7,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1014.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 02:00:00',
#      'temp': 6.1,
#      'dwpt': 2.7,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 14.8,
#      'wpgt': None,
#      'pres': 1015.2,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 03:00:00',
#      'temp': 5.6,
#      'dwpt': 2.2,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 280.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1016.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 04:00:00',
#      'temp': 5.0,
#      'dwpt': 1.7,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1016.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 05:00:00',
#      'temp': 3.9,
#      'dwpt': 0.6,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 300.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1017.3,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 06:00:00',
#      'temp': 3.3,
#      'dwpt': 0.0,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 330.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1017.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 07:00:00',
#      'temp': 0.6,
#      'dwpt': -1.2,
#      'rhum': 88.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 360.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1019.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 08:00:00',
#      'temp': 0.0,
#      'dwpt': -1.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1019.8,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 09:00:00',
#      'temp': 0.0,
#      'dwpt': -1.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 10.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1020.8,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 10:00:00',
#      'temp': -0.6,
#      'dwpt': -1.7,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 20.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1021.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-06 11:00:00',
#      'temp': 1.1,
#      'dwpt': -0.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 30.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1022.0,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-06 12:00:00',
#      'temp': 2.2,
#      'dwpt': -0.1,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 40.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1022.5,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-06 13:00:00',
#      'temp': 2.8,
#      'dwpt': -0.7,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1023.4,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-06 14:00:00',
#      'temp': 3.3,
#      'dwpt': -1.1,
#      'rhum': 73.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1024.1,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-06 15:00:00',
#      'temp': 3.3,
#      'dwpt': -1.1,
#      'rhum': 73.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1024.4,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-06 16:00:00',
#      'temp': 3.9,
#      'dwpt': -1.1,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1025.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-06 17:00:00',
#      'temp': 3.9,
#      'dwpt': -1.1,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1024.4,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-06 18:00:00',
#      'temp': 3.9,
#      'dwpt': -1.1,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 100.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1024.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-06 19:00:00',
#      'temp': 3.9,
#      'dwpt': -1.1,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1023.7,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-06 20:00:00',
#      'temp': 3.9,
#      'dwpt': -1.7,
#      'rhum': 67.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1024.1,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-06 21:00:00',
#      'temp': 3.3,
#      'dwpt': -1.7,
#      'rhum': 70.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 80.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1023.9,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-06 22:00:00',
#      'temp': 3.3,
#      'dwpt': -1.1,
#      'rhum': 73.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 60.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1023.9,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-06 23:00:00',
#      'temp': 2.8,
#      'dwpt': -0.7,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 70.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1023.0,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 00:00:00',
#      'temp': 2.8,
#      'dwpt': -0.7,
#      'rhum': 78.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1022.1,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 01:00:00',
#      'temp': 3.3,
#      'dwpt': 0.0,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 90.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1022.0,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 02:00:00',
#      'temp': 3.9,
#      'dwpt': -0.7,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1021.6,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 03:00:00',
#      'temp': 3.9,
#      'dwpt': -0.7,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1020.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 04:00:00',
#      'temp': 3.9,
#      'dwpt': -0.7,
#      'rhum': 72.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1019.5,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 05:00:00',
#      'temp': 3.9,
#      'dwpt': 0.1,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 130.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1019.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 06:00:00',
#      'temp': 4.4,
#      'dwpt': 0.5,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 110.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1017.4,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 07:00:00',
#      'temp': 5.0,
#      'dwpt': 1.1,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 120.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1015.5,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 08:00:00',
#      'temp': 5.0,
#      'dwpt': 1.1,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1015.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 09:00:00',
#      'temp': 5.0,
#      'dwpt': 1.1,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 31.7,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 10:00:00',
#      'temp': 5.0,
#      'dwpt': 1.7,
#      'rhum': 79.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 140.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1012.6,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-07 11:00:00',
#      'temp': 5.6,
#      'dwpt': 1.7,
#      'rhum': 76.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1011.6,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 12:00:00',
#      'temp': 5.6,
#      'dwpt': 2.2,
#      'rhum': 79.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1009.7,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 13:00:00',
#      'temp': 5.6,
#      'dwpt': 3.3,
#      'rhum': 85.0,
#      'prcp': 0.5,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1009.2,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 14:00:00',
#      'temp': 6.1,
#      'dwpt': 4.4,
#      'rhum': 89.0,
#      'prcp': 0.8,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1006.9,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 15:00:00',
#      'temp': 6.7,
#      'dwpt': 5.0,
#      'rhum': 89.0,
#      'prcp': 1.3,
#      'snow': None,
#      'wdir': 160.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1006.8,
#      'tsun': None,
#      'coco': 8},
#     {'time': '2019-01-07 16:00:00',
#      'temp': 7.2,
#      'dwpt': 6.1,
#      'rhum': 93.0,
#      'prcp': 3.0,
#      'snow': None,
#      'wdir': 150.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1004.5,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 17:00:00',
#      'temp': 7.8,
#      'dwpt': 6.7,
#      'rhum': 93.0,
#      'prcp': 0.2,
#      'snow': None,
#      'wdir': 170.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1002.0,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 18:00:00',
#      'temp': 8.3,
#      'dwpt': 7.9,
#      'rhum': 97.0,
#      'prcp': 1.3,
#      'snow': None,
#      'wdir': 180.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1000.3,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 19:00:00',
#      'temp': 10.0,
#      'dwpt': 8.9,
#      'rhum': 93.0,
#      'prcp': 0.3,
#      'snow': None,
#      'wdir': 200.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 999.2,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 20:00:00',
#      'temp': 10.6,
#      'dwpt': 10.0,
#      'rhum': 96.0,
#      'prcp': 1.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 998.9,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 21:00:00',
#      'temp': 11.7,
#      'dwpt': 10.6,
#      'rhum': 93.0,
#      'prcp': 1.5,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1000.0,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 22:00:00',
#      'temp': 11.7,
#      'dwpt': 9.9,
#      'rhum': 89.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1000.2,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-07 23:00:00',
#      'temp': 11.7,
#      'dwpt': 9.4,
#      'rhum': 86.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1002.7,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-08 00:00:00',
#      'temp': 10.6,
#      'dwpt': 7.8,
#      'rhum': 83.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 35.3,
#      'wpgt': None,
#      'pres': 1003.8,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 01:00:00',
#      'temp': 8.9,
#      'dwpt': 6.2,
#      'rhum': 83.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1005.8,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 02:00:00',
#      'temp': 7.2,
#      'dwpt': 4.3,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1007.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 03:00:00',
#      'temp': 5.6,
#      'dwpt': 3.3,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1007.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 04:00:00',
#      'temp': 5.0,
#      'dwpt': 3.3,
#      'rhum': 89.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1007.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 05:00:00',
#      'temp': 5.0,
#      'dwpt': 3.3,
#      'rhum': 89.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1009.1,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 06:00:00',
#      'temp': 4.4,
#      'dwpt': 3.4,
#      'rhum': 93.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 9.4,
#      'wpgt': None,
#      'pres': 1008.4,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 07:00:00',
#      'temp': 3.9,
#      'dwpt': 2.9,
#      'rhum': 93.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1008.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 08:00:00',
#      'temp': 3.3,
#      'dwpt': 2.9,
#      'rhum': 97.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 0.0,
#      'wpgt': None,
#      'pres': 1008.8,
#      'tsun': None,
#      'coco': 5},
#     {'time': '2019-01-08 09:00:00',
#      'temp': 3.3,
#      'dwpt': 2.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1008.7,
#      'tsun': None,
#      'coco': 5},
#     {'time': '2019-01-08 10:00:00',
#      'temp': 3.3,
#      'dwpt': 2.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1008.6,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 11:00:00',
#      'temp': 2.8,
#      'dwpt': 1.6,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 11.2,
#      'wpgt': None,
#      'pres': 1007.4,
#      'tsun': None,
#      'coco': 5},
#     {'time': '2019-01-08 12:00:00',
#      'temp': 2.8,
#      'dwpt': 2.2,
#      'rhum': 96.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1007.2,
#      'tsun': None,
#      'coco': 5},
#     {'time': '2019-01-08 13:00:00',
#      'temp': 3.3,
#      'dwpt': 2.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 13.0,
#      'wpgt': None,
#      'pres': 1006.5,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 14:00:00',
#      'temp': 3.3,
#      'dwpt': 2.1,
#      'rhum': 92.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 5.4,
#      'wpgt': None,
#      'pres': 1005.3,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-08 15:00:00',
#      'temp': 5.6,
#      'dwpt': 3.3,
#      'rhum': 85.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1006.7,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-08 16:00:00',
#      'temp': 5.6,
#      'dwpt': 2.8,
#      'rhum': 82.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 300.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1007.7,
#      'tsun': None,
#      'coco': 7},
#     {'time': '2019-01-08 17:00:00',
#      'temp': 5.0,
#      'dwpt': 2.2,
#      'rhum': 82.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 300.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1008.1,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-08 18:00:00',
#      'temp': 6.1,
#      'dwpt': 1.6,
#      'rhum': 73.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1008.5,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-08 19:00:00',
#      'temp': 6.7,
#      'dwpt': 1.0,
#      'rhum': 67.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 280.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1009.3,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-08 20:00:00',
#      'temp': 7.2,
#      'dwpt': -4.0,
#      'rhum': 45.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 270.0,
#      'wspd': 35.3,
#      'wpgt': None,
#      'pres': 1010.1,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-08 21:00:00',
#      'temp': 6.7,
#      'dwpt': -5.0,
#      'rhum': 43.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 280.0,
#      'wspd': 46.4,
#      'wpgt': None,
#      'pres': 1010.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-08 22:00:00',
#      'temp': 5.6,
#      'dwpt': -4.3,
#      'rhum': 49.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 280.0,
#      'wspd': 38.9,
#      'wpgt': None,
#      'pres': 1011.5,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-08 23:00:00',
#      'temp': 4.4,
#      'dwpt': -3.4,
#      'rhum': 57.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 280.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1012.2,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-09 00:00:00',
#      'temp': 3.9,
#      'dwpt': -3.4,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 280.0,
#      'wspd': 37.1,
#      'wpgt': None,
#      'pres': 1012.8,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-09 01:00:00',
#      'temp': 2.8,
#      'dwpt': -5.1,
#      'rhum': 56.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 290.0,
#      'wspd': 40.7,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-09 02:00:00',
#      'temp': 1.1,
#      'dwpt': -6.0,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 280.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1014.6,
# ...
#      'prcp': None,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 46.4,
#      'wpgt': None,
#      'pres': 1007.7,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 08:00:00',
#      'temp': -4.4,
#      'dwpt': -8.9,
#      'rhum': 71.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 35.3,
#      'wpgt': None,
#      'pres': 1008.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 09:00:00',
#      'temp': -5.6,
#      'dwpt': -10.0,
#      'rhum': 71.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 31.7,
#      'wpgt': None,
#      'pres': 1009.1,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 10:00:00',
#      'temp': -6.1,
#      'dwpt': -10.7,
#      'rhum': 70.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1009.7,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 11:00:00',
#      'temp': -6.7,
#      'dwpt': -11.1,
#      'rhum': 71.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 31.7,
#      'wpgt': None,
#      'pres': 1010.2,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 12:00:00',
#      'temp': -7.2,
#      'dwpt': -11.0,
#      'rhum': 74.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1010.6,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 13:00:00',
#      'temp': -7.2,
#      'dwpt': -11.7,
#      'rhum': 70.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1011.6,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 14:00:00',
#      'temp': -7.2,
#      'dwpt': -11.7,
#      'rhum': 70.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1012.6,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 15:00:00',
#      'temp': -7.8,
#      'dwpt': -11.6,
#      'rhum': 74.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1013.0,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 16:00:00',
#      'temp': -7.8,
#      'dwpt': -12.1,
#      'rhum': 71.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 35.3,
#      'wpgt': None,
#      'pres': 1013.2,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-29 17:00:00',
#      'temp': -8.3,
#      'dwpt': -13.9,
#      'rhum': 64.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1013.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 18:00:00',
#      'temp': -8.3,
#      'dwpt': -15.5,
#      'rhum': 56.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1012.7,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-29 19:00:00',
#      'temp': -7.8,
#      'dwpt': -12.9,
#      'rhum': 67.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1012.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 20:00:00',
#      'temp': -7.8,
#      'dwpt': -11.6,
#      'rhum': 74.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 210.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 21:00:00',
#      'temp': -8.3,
#      'dwpt': -12.8,
#      'rhum': 70.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 35.3,
#      'wpgt': None,
#      'pres': 1012.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-29 22:00:00',
#      'temp': -9.4,
#      'dwpt': -17.2,
#      'rhum': 53.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 40.7,
#      'wpgt': None,
#      'pres': 1013.6,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-29 23:00:00',
#      'temp': -10.0,
#      'dwpt': -16.7,
#      'rhum': 58.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1014.6,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-30 00:00:00',
#      'temp': -10.0,
#      'dwpt': -17.8,
#      'rhum': 53.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1014.9,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 01:00:00',
#      'temp': -10.0,
#      'dwpt': -13.9,
#      'rhum': 73.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1016.5,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 02:00:00',
#      'temp': -10.6,
#      'dwpt': -18.8,
#      'rhum': 51.0,
#      'prcp': 0.3,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 40.7,
#      'wpgt': None,
#      'pres': 1016.4,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-30 03:00:00',
#      'temp': -12.2,
#      'dwpt': -20.5,
#      'rhum': 50.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1016.8,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 04:00:00',
#      'temp': -12.2,
#      'dwpt': -20.5,
#      'rhum': 50.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1016.4,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 05:00:00',
#      'temp': -12.8,
#      'dwpt': -20.0,
#      'rhum': 55.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1016.0,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 06:00:00',
#      'temp': -13.3,
#      'dwpt': -19.4,
#      'rhum': 60.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1015.6,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 07:00:00',
#      'temp': -13.9,
#      'dwpt': -20.6,
#      'rhum': 57.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1015.0,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 08:00:00',
#      'temp': -14.4,
#      'dwpt': -21.7,
#      'rhum': 54.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1014.5,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 09:00:00',
#      'temp': -15.0,
#      'dwpt': -22.2,
#      'rhum': 54.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 31.7,
#      'wpgt': None,
#      'pres': 1014.0,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 10:00:00',
#      'temp': -16.1,
#      'dwpt': -23.3,
#      'rhum': 54.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1014.2,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 11:00:00',
#      'temp': -17.2,
#      'dwpt': -24.3,
#      'rhum': 54.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 35.3,
#      'wpgt': None,
#      'pres': 1014.4,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 12:00:00',
#      'temp': -17.2,
#      'dwpt': -23.9,
#      'rhum': 56.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 38.9,
#      'wpgt': None,
#      'pres': 1014.8,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 13:00:00',
#      'temp': -17.8,
#      'dwpt': -25.5,
#      'rhum': 51.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 40.7,
#      'wpgt': None,
#      'pres': 1016.2,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 14:00:00',
#      'temp': -18.3,
#      'dwpt': -26.6,
#      'rhum': 48.0,
#      'prcp': None,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1017.9,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 15:00:00',
#      'temp': -18.9,
#      'dwpt': -27.2,
#      'rhum': 48.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 37.1,
#      'wpgt': None,
#      'pres': 1019.3,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-30 16:00:00',
#      'temp': -18.9,
#      'dwpt': -27.9,
#      'rhum': 45.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 48.2,
#      'wpgt': None,
#      'pres': 1020.9,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-30 17:00:00',
#      'temp': -18.9,
#      'dwpt': -27.2,
#      'rhum': 48.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 42.5,
#      'wpgt': None,
#      'pres': 1022.2,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-30 18:00:00',
#      'temp': -18.9,
#      'dwpt': -25.7,
#      'rhum': 55.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 42.5,
#      'wpgt': None,
#      'pres': 1022.8,
#      'tsun': None,
#      'coco': 4},
#     {'time': '2019-01-30 19:00:00',
#      'temp': -18.3,
#      'dwpt': -25.5,
#      'rhum': 53.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 31.7,
#      'wpgt': None,
#      'pres': 1023.5,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-30 20:00:00',
#      'temp': -18.3,
#      'dwpt': -26.2,
#      'rhum': 50.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 42.5,
#      'wpgt': None,
#      'pres': 1024.0,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-30 21:00:00',
#      'temp': -18.3,
#      'dwpt': -27.1,
#      'rhum': 46.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1024.9,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-30 22:00:00',
#      'temp': -18.3,
#      'dwpt': -26.6,
#      'rhum': 48.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 35.3,
#      'wpgt': None,
#      'pres': 1025.3,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-30 23:00:00',
#      'temp': -18.9,
#      'dwpt': -26.7,
#      'rhum': 50.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1025.3,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-31 00:00:00',
#      'temp': -18.3,
#      'dwpt': -25.5,
#      'rhum': 53.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1026.0,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-31 01:00:00',
#      'temp': -18.3,
#      'dwpt': -24.4,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1026.4,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-31 02:00:00',
#      'temp': -18.3,
#      'dwpt': -24.4,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 33.5,
#      'wpgt': None,
#      'pres': 1026.9,
#      'tsun': None,
#      'coco': 3},
#     {'time': '2019-01-31 03:00:00',
#      'temp': -18.3,
#      'dwpt': -24.4,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 37.1,
#      'wpgt': None,
#      'pres': 1027.2,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-31 04:00:00',
#      'temp': -18.3,
#      'dwpt': -24.4,
#      'rhum': 59.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 31.7,
#      'wpgt': None,
#      'pres': 1027.6,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-31 05:00:00',
#      'temp': -18.3,
#      'dwpt': -24.0,
#      'rhum': 61.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1028.0,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-31 06:00:00',
#      'temp': -18.9,
#      'dwpt': -23.8,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1028.5,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-31 07:00:00',
#      'temp': -18.3,
#      'dwpt': -23.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1028.5,
#      'tsun': None,
#      'coco': 14},
#     {'time': '2019-01-31 08:00:00',
#      'temp': -18.3,
#      'dwpt': -23.3,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1029.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 09:00:00',
#      'temp': -18.9,
#      'dwpt': -23.8,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 16.6,
#      'wpgt': None,
#      'pres': 1029.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 10:00:00',
#      'temp': -18.9,
#      'dwpt': -23.8,
#      'rhum': 65.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1029.3,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 11:00:00',
#      'temp': -18.9,
#      'dwpt': -24.4,
#      'rhum': 62.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1029.8,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 12:00:00',
#      'temp': -18.9,
#      'dwpt': -24.4,
#      'rhum': 62.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 220.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1030.1,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 13:00:00',
#      'temp': -18.9,
#      'dwpt': -24.4,
#      'rhum': 62.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 20.5,
#      'wpgt': None,
#      'pres': 1030.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 14:00:00',
#      'temp': -18.3,
#      'dwpt': -24.9,
#      'rhum': 56.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1030.9,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 15:00:00',
#      'temp': -17.2,
#      'dwpt': -24.9,
#      'rhum': 51.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 240.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1031.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 16:00:00',
#      'temp': -16.1,
#      'dwpt': -24.4,
#      'rhum': 49.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 25.9,
#      'wpgt': None,
#      'pres': 1031.5,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 17:00:00',
#      'temp': -15.6,
#      'dwpt': -25.1,
#      'rhum': 44.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 35.3,
#      'wpgt': None,
#      'pres': 1031.5,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 18:00:00',
#      'temp': -14.4,
#      'dwpt': -24.0,
#      'rhum': 44.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1030.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 19:00:00',
#      'temp': -13.9,
#      'dwpt': -23.3,
#      'rhum': 45.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 260.0,
#      'wspd': 24.1,
#      'wpgt': None,
#      'pres': 1030.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 20:00:00',
#      'temp': -13.9,
#      'dwpt': -23.8,
#      'rhum': 43.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 230.0,
#      'wspd': 29.5,
#      'wpgt': None,
#      'pres': 1030.4,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 21:00:00',
#      'temp': -13.3,
#      'dwpt': -23.8,
#      'rhum': 41.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 27.7,
#      'wpgt': None,
#      'pres': 1030.7,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 22:00:00',
#      'temp': -13.9,
#      'dwpt': -23.3,
#      'rhum': 45.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 22.3,
#      'wpgt': None,
#      'pres': 1031.0,
#      'tsun': None,
#      'coco': 2},
#     {'time': '2019-01-31 23:00:00',
#      'temp': -14.4,
#      'dwpt': -23.3,
#      'rhum': 47.0,
#      'prcp': 0.0,
#      'snow': None,
#      'wdir': 250.0,
#      'wspd': 18.4,
#      'wpgt': None,
#      'pres': 1031.3,
#      'tsun': None,
#      'coco': 2}]}]}

# %%
weather_hourly_df = pd.DataFrame(weather_hourly_dict)
weather_hourly_df
# Out:
#                 extracted_at airport_code  station_id  \
# 0 2024-10-16 12:43:08.312947          ORD       72530
# 1 2024-10-16 12:43:09.188164          MSP       72658
# 2 2024-10-16 12:43:10.064336          DTW       72537
# 3 2024-10-16 12:43:10.950486          MKE       72640
# 4 2024-10-16 12:43:11.732107          CLE       72524
#
#                                       extracted_data
# 0  {'meta': {'generated': '2024-10-16 10:43:08'},...
# 1  {'meta': {'generated': '2024-10-16 10:43:09'},...
# 2  {'meta': {'generated': '2024-10-16 10:43:09'},...
# 3  {'meta': {'generated': '2024-10-16 10:43:10'},...
# 4  {'meta': {'generated': '2024-10-16 10:43:11'},...

# %% [markdown]
# ### Loading the data into the DB

# %%
# getting API and DB credentials - Alternative 1: dotenv_values()

config = dotenv_values()
 
pg_user = config['POSTGRES_USER'] # align the key labels with your .env file
pg_host = config['POSTGRES_HOST']
pg_port = config['POSTGRES_PORT']
pg_db = config['POSTGRES_DB']
pg_schema = 'p_below_zero'
pg_pass = config['POSTGRES_PASS']

# %% [markdown]
# Updating the URL

# %%
# updating the url
url = f'postgresql://{pg_user}:{pg_pass}@{pg_host}:{pg_port}/{pg_db}'

# creating the engine
engine = create_engine(url, echo=False)

# %%
engine.url # checking the url (pass is hidden)
# Out:
# postgresql://shaunkutsanzira:***@data-analytics-course-2.c8g8r1deus2v.eu-central-1.rds.amazonaws.com:5432/hh_analytics_24_2

# %%
# defining data types for the DB
dtype_dict = {
    'extracted_at':types.DateTime,
    'airport_code': types.String,
    'station_id': types.Integer,
    'extracted_data':postgres_json
             }

# %%
# writing dataframe to DB
weather_hourly_df.to_sql(name = 'weather_jan_hourly_raw', 
                       con = engine, 
                       schema = pg_schema, 
                       if_exists='replace', 
                       dtype=dtype_dict,
                       index=False
)
# Out:
# 5
